# %% [markdown]
# # Predict Customer Churn

# %% [markdown]
# ## Import Libraries

# %%
import shap
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report

import importlib
from debug import churn_library as clib
from debug import constants
from constants import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 18
#      15 from sklearn.metrics import classification_report
#      17 import importlib
# ---> 18 from debug import churn_library as clib
#      19 from debug import constants
#      20 from constants import *
#
# File ~\Churn_Udacity\debug\churn_library.py:17
#      14 import matplotlib.pyplot as plt
#      15 import seaborn as sns
# ---> 17 from sklearn.metrics import plot_roc_curve, classification_report
#      18 from sklearn.model_selection import GridSearchCV
#      19 from sklearn.ensemble import RandomForestClassifier
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (c:\users\pouya\venv\lib\site-packages\sklearn\metrics\__init__.py)

# %%
# importlib.reload(churn_library)
# Out:
# <module 'churn_library' from '/workspace/home/churn_library.py'>

# %%
import os
os.environ['QT_QPA_PLATFORM']='offscreen'

# %% [markdown]
# ## Import the data

# %%
df = clib.import_data(DATA_PATH)
df.head()
# Out:
# reading the csv file from {} path ./data/bank_data.csv
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#    Dependent_count Education_Level Marital_Status Income_Category  \
# 0                3     High School        Married     $60K - $80K
# 1                5        Graduate         Single  Less than $40K
# 2                3        Graduate        Married    $80K - $120K
# 3                4     High School        Unknown  Less than $40K
# 4                3      Uneducated        Married     $60K - $80K
#
#   Card_Category          ...            Months_Inactive_12_mon  \
# ...

# %%
df.shape
# Out:
# (10127, 22)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0     CLIENTNUM  Customer_Age  Dependent_count  \
# count  10127.000000  1.012700e+04  10127.000000     10127.000000
# mean    5063.000000  7.391776e+08     46.325960         2.346203
# std     2923.557422  3.690378e+07      8.016814         1.298908
# min        0.000000  7.080821e+08     26.000000         0.000000
# 25%     2531.500000  7.130368e+08     41.000000         1.000000
# 50%     5063.000000  7.179264e+08     46.000000         2.000000
# 75%     7594.500000  7.731435e+08     52.000000         3.000000
# max    10126.000000  8.283431e+08     73.000000         5.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        35.928409                  3.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min         13.000000                  1.000000                0.000000
# ...

# %%
df[RESPONSE] = df['Attrition_Flag'].apply(lambda val: 0 if val == "Existing Customer" else 1)

# %% [markdown]
# ## 3. Perform Exploratory Data Analysis and Feature Engineering

# %%
## Perform EDA and save figures in images folder
clib.perform_eda(df, quant_columns=QUANT_COLS, 
            cat_columns = CAT_COLS)
# Out:
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
## create encoded variables for categorical variables
df = clib.encoder_helper(df, CAT_COLS, RESPONSE)

# %%
## Train test split
X_train, X_test, y_train, y_test = clib.perform_feature_engineering(df, FINAL_COLUMNS)

# %%
X_train.shape, df.shape
# Out:
# ((7088, 19), (10127, 28))

# %% [markdown]
# ## 4. Train and calculate model performance

# %%
clib.train_models(X_train, X_test, y_train, y_test)
# Out:
# random forest results
# test results
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2543
#            1       0.93      0.80      0.86       496
#
#     accuracy                           0.96      3039
#    macro avg       0.95      0.90      0.92      3039
# weighted avg       0.96      0.96      0.96      3039
#
# train results
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5957
#            1       1.00      1.00      1.00      1131
#
#     accuracy                           1.00      7088
#    macro avg       1.00      1.00      1.00      7088
# weighted avg       1.00      1.00      1.00      7088
#
# logistic regression results
# test results
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      2543
#            1       0.71      0.45      0.55       496
#
# ...

# %%
lrc_plot = plot_roc_curve(lrc, X_test, y_test)

# %%
# plots
plt.figure(figsize=(15, 8))
ax = plt.gca()
rfc_disp = plot_roc_curve(cv_rfc.best_estimator_, X_test, y_test, ax=ax, alpha=0.8)
lrc_plot.plot(ax=ax, alpha=0.8)
plt.show()

# %%
## load models
rfc_model = joblib.load('./models/rfc_model.pkl')
lr_model = joblib.load('./models/logistic_model.pkl')

# %%
lrc_plot = plot_roc_curve(lr_model, X_test, y_test)

# %%
plt.figure(figsize=(15, 8))
ax = plt.gca()
rfc_disp = plot_roc_curve(rfc_model, X_test, y_test, ax=ax, alpha=0.8)
lrc_plot.plot(ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# ## Feature Importance using SHAP and Feature_importance_ for Random Forest model

# %%
explainer = shap.TreeExplainer(rfc_model)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
output_pth = PATH_PREFIX + '/images/results/feature_importance_plot.png'
clib.feature_importance_plot(rfc_model, X, output_pth)
# Out:
# Saving the feature importance plot in /workspace/home/images/results/feature_importance_plot.png path

# %% [markdown]
# ## Create and save classification report image

# %%
PATH_PREFIX ='/workspace/home'
classification_report_image(y_train,
                                y_test,
                                y_train_preds_lr,
                                y_train_preds_rf,
                                y_test_preds_lr,
                                y_test_preds_rf)

# %%
from pathlib import Path
